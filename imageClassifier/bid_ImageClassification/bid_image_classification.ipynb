# %% [markdown]
# # 1. Setup and Load Data

# %% [markdown]
# ## 1.1 Install Dependencies and Setup

# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (2.13.0)
# Collecting opencv-python
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/b1/ca/69f7f2204d5779ad939123cce9735f76db8f50e2b482e45b413c585b0b27/opencv_python-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_python-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/f6/22/9c31044ff7339c63727a135872e5cb59564f11625372a81c3eebf148f4af/matplotlib-3.7.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading matplotlib-3.7.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: tensorflow-macos==2.13.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.56.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.1)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/88/e3/696e96ee197b1f60242d12b215332af9fc1961c81990c8b5630b89b34ce6/contourpy-1.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading contourpy-1.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/32/9a/6fe79bfc6b23f2d5e24a7d9d3402df34128b5df939777d57b94ac8251fa5/fonttools-4.42.0-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading fonttools-4.42.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 5.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Using cached kiwisolver-1.4.4-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Obtaining dependency information for pillow>=6.2.0 from https://files.pythonhosted.org/packages/b7/ad/71982d18fd28ed1f93c31b8648f980ebdbdbcf7d8c9c9b4af59290914ce9/Pillow-10.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading Pillow-10.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/hasana1/Desktop/bid_ML/imageclassification/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.2)
# Using cached opencv_python-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
# Using cached matplotlib-3.7.2-cp311-cp311-macosx_11_0_arm64.whl (7.3 MB)
# Using cached contourpy-1.1.0-cp311-cp311-macosx_11_0_arm64.whl (229 kB)
# Using cached fonttools-4.42.0-cp311-cp311-macosx_10_9_universal2.whl (2.7 MB)
# Using cached Pillow-10.0.0-cp311-cp311-macosx_11_0_arm64.whl (3.1 MB)
# Installing collected packages: pyparsing, pillow, opencv-python, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.42.0 kiwisolver-1.4.4 matplotlib-3.7.2 opencv-python-4.8.0.74 pillow-10.0.0 pyparsing-3.0.9

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- ---------
# absl-py                 1.4.0
# appnope                 0.1.3
# asttokens               2.2.1
# astunparse              1.6.3
# backcall                0.2.0
# cachetools              5.3.1
# certifi                 2023.7.22
# charset-normalizer      3.2.0
# comm                    0.1.4
# contourpy               1.1.0
# cycler                  0.11.0
# debugpy                 1.6.7
# decorator               5.1.1
# executing               1.2.0
# flatbuffers             23.5.26
# fonttools               4.42.0
# gast                    0.4.0
# google-auth             2.22.0
# google-auth-oauthlib    1.0.0
# google-pasta            0.2.0
# grpcio                  1.56.2
# h5py                    3.9.0
# idna                    3.4
# ipykernel               6.25.1
# ipython                 8.14.0
# jedi                    0.19.0
# jupyter_client          8.3.0
# jupyter_core            5.3.1
# keras                   2.13.1
# kiwisolver              1.4.4
# libclang                16.0.6
# Markdown                3.4.4
# MarkupSafe              2.1.3
# matplotlib              3.7.2
# matplotlib-inline       0.1.6
# nest-asyncio            1.5.7
# numpy                   1.24.3
# oauthlib                3.2.2
# opencv-python           4.8.0.74
# opt-einsum              3.3.0
# packaging               23.1
# parso                   0.8.3
# pexpect                 4.8.0
# pickleshare             0.7.5
# Pillow                  10.0.0
# pip                     23.2.1
# platformdirs            3.10.0
# prompt-toolkit          3.0.39
# protobuf                4.23.4
# psutil                  5.9.5
# ptyprocess              0.7.0
# pure-eval               0.2.2
# pyasn1                  0.5.0
# pyasn1-modules          0.3.0
# Pygments                2.16.1
# pyparsing               3.0.9
# python-dateutil         2.8.2
# python-version          0.0.2
# pyzmq                   25.1.0
# requests                2.31.0
# requests-oauthlib       1.3.1
# rsa                     4.9
# setuptools              65.5.0
# six                     1.16.0
# stack-data              0.6.2
# tensorboard             2.13.0
# tensorboard-data-server 0.7.1
# tensorflow              2.13.0
# tensorflow-estimator    2.13.0
# tensorflow-macos        2.13.0
# termcolor               2.3.0
# tornado                 6.3.2
# traitlets               5.9.0
# typing_extensions       4.5.0
# urllib3                 1.26.16
# wcwidth                 0.2.6
# Werkzeug                2.3.6
# wheel                   0.41.1
# wrapt                   1.15.0

# %%
import tensorflow as tf
import os

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## 1.2 Remove dodgy images

# %%
import cv2
import imghdr

# %%
data_dir = 'data'

# %%
img_exts = ['jpeg', 'jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in img_exts:
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Issue with image {}'.format(image_path))
# Out:
# Issue with image data/images26.jpg
# Issue with image data/e162ccda8ce0f197f8863f327add9233.jpg
# Issue with image data/05-12-21-happy-people.jpg
# Issue with image data/GettyImages-871518740-1024x707.jpg
# Issue with image data/7-principles-of-successful-and-happy-people.png
# Issue with image data/how-happy-are-healthy-people.jpg
# Issue with image data/physed-happiness-facebookJumbo.jpg
# Issue with image data/170404-happy-workers-feature.jpg
# Issue with image data/image18.jpeg
# Issue with image data/MV5BMTM3ODM0NTQ1MF5BMl5BanBnXkFtZTcwMzAxMTM5OA._V1_.jpg
# Issue with image data/images31.jpg
# Issue with image data/Happy-people-raise-happy-kids-raise-yourself-first.jpg
# Issue with image data/habits-that-define-very-happy-people.jpg
# Issue with image data/goup-happy-people-group-jumping-isolated-white-background-35582232.jpg
# Issue with image data/1902587.jpg
# Issue with image data/o-HAPPY-facebook.jpg
# Issue with image data/07-120104-happy_people_are_not_nice_people.jpg
# Issue with image data/happy-people-13772392.jpg
# Issue with image data/images30.jpg
# Issue with image data/image15.jpeg
# Issue with image data/young-and-happy-people-vector-15114154.jpg
# Issue with image data/maxresdefault2.jpg
# Issue with image data/bigstock-Portrait-Of-Smiling-Employees-272904928-min-scaled.jpg
# Issue with image data/happy-people-1024x768.jpeg
# Issue with image data/1902540.jpg
# Issue with image data/hqdefault.jpg
# Issue with image data/image19.jpeg
# Issue with image data/images36.jpg
# Issue with image data/images22.jpg
# Issue with image data/tmp_6mv7xy_5d5b15258a507669_GettyImages-847741712.jpg
# Issue with image data/happy-people-14410042.jpg
# Issue with image data/Top-Secrets-of-How-to-be-Happy.jpg
# Issue with image data/Happy_People_Happy_Man.jpg
# Issue with image data/happiness.jpg
# Issue with image data/images6.jpg
# Issue with image data/maxresdefault.jpg
# Issue with image data/HAPPY-PEOPLE-CLUB-LOGO.jpg
# Issue with image data/1000_F_42220133_toAU6USGY9jVr2XJFLssfG00cSYIJ173.jpg
# Issue with image data/happy-person.jpeg
# Issue with image data/THPC_Logo-jpeg.jpg
# Issue with image data/Travis-Bradberry-Happy.jpg
# Issue with image data/1HEoLBLidT2u4mhJ0oiDgig.png
# Issue with image data/the-habits-of-happy-people-a-meditation-day-course-611337.jpg
# Issue with image data/habits-of-happy-people-cr3.jpg
# Issue with image data/happy-people-702x336.jpg
# Issue with image data/happy-woman-in-nature-at-sunset.jpg
# Issue with image data/image25.jpeg
# Issue with image data/_happy_jumping_on_beach-40815.jpg
# Issue with image data/A_Sep20_14_1189155141.jpg
# Issue with image data/traitshappypeople.jpg
# Issue with image data/1920px-face-smile.svg_.png.jpg
# Issue with image data/Happy-people-800x533.jpg
# Issue with image data/Screen-Shot-2012-10-23-at-12.57.22-PM.png
# Issue with image data/How_Happy_Are_People_at_Work.jpg
# Issue with image data/1902539.jpg
# Issue with image data/227-2271622_happy-people-business-team-celebrating-png.png
# Issue with image data/iStock-1212931050.jpg
# Issue with image data/happy-people21.jpg
# Issue with image data/jumping_for_joy_for_3_kinds_of_happy_people.jpg
# Issue with image data/happy-people-group-fb.jpg
# Issue with image data/7Y57w0983emdERAoQylUHIGkoEk1cIFvPkXDbeA2lVA.jpg
# Issue with image data/what-makes-people-happy.jpeg
# Issue with image data/happy-people.jpg
# Issue with image data/image26.jpeg
# Issue with image data/happy-people-black-and-white-720x360.jpg
# Issue with image data/fiendship-concept-smiling-friends-communication-weekend-university-123724503.jpg
# Issue with image data/getty_494581822_130796.jpg
# Issue with image data/image27.jpeg
# Issue with image data/7-Habits-of-Happy-People-image.jpeg
# Issue with image data/Happiness-Habits-10-Things-Happy-People-Do-Before-Bed.jpg
# Issue with image data/960x0.jpg
# Issue with image data/happy-people-vector-839522.jpg
# Issue with image data/habits-of-happy-people.jpg
# Issue with image data/smile.woman_.jpg
# Issue with image data/How-to-Be-Happy_1200x628-facebook.jpg
# Issue with image data/friends-happy-190821-800x450.jpg
# Issue with image data/HappyPeopleBanner.png
# Issue with image data/getty_152414899_97046097045006_68075.jpg
# Issue with image data/GettyImages-565706549-949x534.jpg
# Issue with image data/image20.jpeg
# Issue with image data/images12.jpg
# Issue with image data/image16.jpeg
# Issue with image data/1-2.jpg
# Issue with image data/blog_image_20180219221810890.jpg
# Issue with image data/8cxKy5g9i.jpg
# Issue with image data/getty_505175324_2000131020009280246_158016.jpg
# Issue with image data/group-of-happy-people-2.jpg
# Issue with image data/happinessa.jpg
# Issue with image data/happy-people_1463241208.jpg
# Issue with image data/getty_478389113_970647970450091_99776.jpg
# Issue with image data/11-Habits-of-Truly-Happy-People.jpg
# Issue with image data/154006829.jpg
# Issue with image data/hdptcar-fi-2.jpg
# Issue with image data/web3-happy-people-outside-smile-sun-nature-eduardo-dutra-620857-unsplash.jpg
# Issue with image data/images28.jpg
# Issue with image data/image17.jpeg
# Issue with image data/happy-people-vector-29209040.jpg
# Issue with image data/brady-bunch-3.jpg
# Issue with image data/happypeople-1024x679.jpg
# Issue with image data/images17.jpg
# Issue with image data/happy-girl-in-leaves.jpg
# Issue with image data/maxresdefault4.jpg
# Issue with image data/sad-person-concept-vector-26538685.jpg
# Issue with image data/sad-people-icon-2CCHXB2.jpg
# Issue with image data/vh6to.jpg
# Issue with image data/dreamstime_s_101440985.jpg
# Issue with image data/iStock_000001932580XSmall.jpg
# Issue with image data/Depression-More-Than-Being-Sad.jpg
# Issue with image data/sadness-inside-out-today-main-tease-191018.jpg
# Issue with image data/maxresdefault2.jpg
# Issue with image data/5360f7e3f9a01bb1aa10654514442436.500x500x1.jpg
# Issue with image data/maxresdefault3.jpg
# Issue with image data/SAD.jpg
# Issue with image data/person-super-depressed.jpg
# Issue with image data/AdobeStock_221688877-copy.jpg
# Issue with image data/6-Best-and-worst-things-to-say.jpg
# Issue with image data/52672678._SX318_SY475_.jpg
# Issue with image data/sad-human-figure-depression-concept-drawing-frank-ramspott.jpg
# Issue with image data/sad-talks-for-sad-people-fb13.png
# Issue with image data/73705bd7debb66c2afc780a22c223804.jpg
# Issue with image data/0x0.jpg
# Issue with image data/maxresdefault.jpg
# Issue with image data/sad-people-vector-2153909.jpg
# Issue with image data/sad-group-people-problems-17033671.jpg
# Issue with image data/original.jpg
# Issue with image data/1000_F_58495935_Nr9VzQljLyN3RKKhGDGxQDBEkqIeLzrZ.jpg
# Issue with image data/Make-someone-sad-happy.jpg
# Issue with image data/dark-depression-mood-people-wallpaper-preview.jpg
# Issue with image data/51079685_M-1280x429.jpg
# Issue with image data/504212.jpg
# Issue with image data/isolated-girl-crying-over-makeup-sad-person-concept-isolated-white-174239618.jpg
# Issue with image data/sad-people.jpg
# Issue with image data/getty_501650894_118886.jpg
# Issue with image data/8iAb9k4aT.jpg
# Issue with image data/pablo-varela-311608.jpg
# Issue with image data/images3.jpg
# Issue with image data/280-2804580_sad-people-png-sad-person-png-transparent-png.png
# Issue with image data/crying-at-work.jpg
# Issue with image data/sad-depressed-man.jpg
# Issue with image data/gettyimages-957787572.jpg
# Issue with image data/at-home-sad-sofa-300x200.jpg
# Issue with image data/artworks-inq7uS3bz9CqNd3d-fqs6TA-t500x500.jpg
# Issue with image data/sadness.jpg
# Issue with image data/sad-people-vector-26812552.jpg
# Issue with image data/sad-looking-man.jpg
# Issue with image data/766x415_Depression_vs_Sadness.jpg
# Issue with image data/de2a0f4d137d0aeb839d43a2ea9b6c72.jpg
# Issue with image data/DD-blogpost-SAD-940x492.png
# Issue with image data/Depressed-woman-covering-her-eyes.jpg
# Issue with image data/sad-woman.jpg
# Issue with image data/b11b520b0818895ae5563d1e70294052.jpg
# Issue with image data/iStock-174971863.jpg
# Issue with image data/405-4050267_sad-people-png-sad-person-transparent-background-png.png
# Issue with image data/image20.jpeg
# Issue with image data/images10.jpg
# Issue with image data/artworks-pQBql6xWFe6JFOp4-FRtE5g-t500x500.jpg
# Issue with image data/smiling-man-crowd-sad-people-vector-58533122.jpg
# Issue with image data/image-20160914-4963-19knfh1.jpg
# Issue with image data/Crying-girl.jpg
# Issue with image data/screen-shot-2014-07-31-at-6-09-12-pm.png
# Issue with image data/sad-people-png-favpng-XVec9sHvxbuQCQm0RmGgQx3bA.jpg
# Issue with image data/Sad-People-Bad-People-Luckie-1050x700.jpg
# Issue with image data/running-mascara.jpg
# Issue with image data/boy-with-head-down.jpg
# Issue with image data/51079685_M.jpg
# Issue with image data/7RNXwSxCAKL8vGtXG2ZkyD.jpg
# Issue with image data/fTw5aVC5_400x400.jpg
# Issue with image data/b2ap3_large_happy-sad-unsplash-850x575.jpg
# Issue with image data/landscape-4209944_1280.jpg
# Issue with image data/sad-big-SS.jpg
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/images26.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/e162ccda8ce0f197f8863f327add9233.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/05-12-21-happy-people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/GettyImages-871518740-1024x707.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/7-principles-of-successful-and-happy-people.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/how-happy-are-healthy-people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/physed-happiness-facebookJumbo.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/170404-happy-workers-feature.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/image18.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/MV5BMTM3ODM0NTQ1MF5BMl5BanBnXkFtZTcwMzAxMTM5OA._V1_.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/images31.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.858] global loadsave.cpp:248 findDecoder imread_('data/Happy-people-raise-happy-kids-raise-yourself-first.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/habits-that-define-very-happy-people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/goup-happy-people-group-jumping-isolated-white-background-35582232.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/1902587.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/o-HAPPY-facebook.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/07-120104-happy_people_are_not_nice_people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/happy-people-13772392.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/images30.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/image15.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/young-and-happy-people-vector-15114154.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/maxresdefault2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/bigstock-Portrait-Of-Smiling-Employees-272904928-min-scaled.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/happy-people-1024x768.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/1902540.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/hqdefault.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/image19.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/images36.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/images22.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/tmp_6mv7xy_5d5b15258a507669_GettyImages-847741712.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/happy-people-14410042.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/Top-Secrets-of-How-to-be-Happy.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/Happy_People_Happy_Man.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.859] global loadsave.cpp:248 findDecoder imread_('data/happiness.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/images6.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/maxresdefault.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/HAPPY-PEOPLE-CLUB-LOGO.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/1000_F_42220133_toAU6USGY9jVr2XJFLssfG00cSYIJ173.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/happy-person.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/THPC_Logo-jpeg.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/Travis-Bradberry-Happy.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/1HEoLBLidT2u4mhJ0oiDgig.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/the-habits-of-happy-people-a-meditation-day-course-611337.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/habits-of-happy-people-cr3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/happy-people-702x336.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/happy-woman-in-nature-at-sunset.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.860] global loadsave.cpp:248 findDecoder imread_('data/image25.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/_happy_jumping_on_beach-40815.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/A_Sep20_14_1189155141.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/traitshappypeople.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/1920px-face-smile.svg_.png.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/Happy-people-800x533.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/Screen-Shot-2012-10-23-at-12.57.22-PM.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/How_Happy_Are_People_at_Work.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/1902539.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/227-2271622_happy-people-business-team-celebrating-png.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/iStock-1212931050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/happy-people21.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/jumping_for_joy_for_3_kinds_of_happy_people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/happy-people-group-fb.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/7Y57w0983emdERAoQylUHIGkoEk1cIFvPkXDbeA2lVA.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/what-makes-people-happy.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/happy-people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/image26.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/happy-people-black-and-white-720x360.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/fiendship-concept-smiling-friends-communication-weekend-university-123724503.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/getty_494581822_130796.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/image27.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/7-Habits-of-Happy-People-image.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/Happiness-Habits-10-Things-Happy-People-Do-Before-Bed.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/960x0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/happy-people-vector-839522.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.861] global loadsave.cpp:248 findDecoder imread_('data/habits-of-happy-people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/smile.woman_.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/How-to-Be-Happy_1200x628-facebook.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/friends-happy-190821-800x450.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/HappyPeopleBanner.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/getty_152414899_97046097045006_68075.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/GettyImages-565706549-949x534.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/image20.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/images12.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/image16.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/1-2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/blog_image_20180219221810890.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/8cxKy5g9i.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/getty_505175324_2000131020009280246_158016.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/group-of-happy-people-2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/happinessa.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/happy-people_1463241208.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/getty_478389113_970647970450091_99776.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/11-Habits-of-Truly-Happy-People.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/154006829.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/hdptcar-fi-2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/web3-happy-people-outside-smile-sun-nature-eduardo-dutra-620857-unsplash.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/images28.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/image17.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/happy-people-vector-29209040.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/brady-bunch-3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/happypeople-1024x679.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/images17.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.862] global loadsave.cpp:248 findDecoder imread_('data/happy-girl-in-leaves.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/maxresdefault4.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/sad-person-concept-vector-26538685.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/sad-people-icon-2CCHXB2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/vh6to.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/dreamstime_s_101440985.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/iStock_000001932580XSmall.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/Depression-More-Than-Being-Sad.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/sadness-inside-out-today-main-tease-191018.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/maxresdefault2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/5360f7e3f9a01bb1aa10654514442436.500x500x1.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/maxresdefault3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/SAD.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/person-super-depressed.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/AdobeStock_221688877-copy.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/6-Best-and-worst-things-to-say.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/52672678._SX318_SY475_.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/sad-human-figure-depression-concept-drawing-frank-ramspott.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/sad-talks-for-sad-people-fb13.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/73705bd7debb66c2afc780a22c223804.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/0x0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/maxresdefault.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/sad-people-vector-2153909.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/sad-group-people-problems-17033671.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/original.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.863] global loadsave.cpp:248 findDecoder imread_('data/1000_F_58495935_Nr9VzQljLyN3RKKhGDGxQDBEkqIeLzrZ.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/Make-someone-sad-happy.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/dark-depression-mood-people-wallpaper-preview.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/51079685_M-1280x429.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/504212.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/isolated-girl-crying-over-makeup-sad-person-concept-isolated-white-174239618.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/sad-people.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/getty_501650894_118886.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/8iAb9k4aT.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/pablo-varela-311608.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/images3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/280-2804580_sad-people-png-sad-person-png-transparent-png.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/crying-at-work.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/sad-depressed-man.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/gettyimages-957787572.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/at-home-sad-sofa-300x200.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/artworks-inq7uS3bz9CqNd3d-fqs6TA-t500x500.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/sadness.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/sad-people-vector-26812552.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/sad-looking-man.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/766x415_Depression_vs_Sadness.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/de2a0f4d137d0aeb839d43a2ea9b6c72.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/DD-blogpost-SAD-940x492.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/Depressed-woman-covering-her-eyes.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/sad-woman.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/b11b520b0818895ae5563d1e70294052.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/iStock-174971863.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/405-4050267_sad-people-png-sad-person-transparent-background-png.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/image20.jpeg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/images10.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/artworks-pQBql6xWFe6JFOp4-FRtE5g-t500x500.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/smiling-man-crowd-sad-people-vector-58533122.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/image-20160914-4963-19knfh1.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.864] global loadsave.cpp:248 findDecoder imread_('data/Crying-girl.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/screen-shot-2014-07-31-at-6-09-12-pm.png'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/sad-people-png-favpng-XVec9sHvxbuQCQm0RmGgQx3bA.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/Sad-People-Bad-People-Luckie-1050x700.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/running-mascara.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/boy-with-head-down.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/51079685_M.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/7RNXwSxCAKL8vGtXG2ZkyD.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/fTw5aVC5_400x400.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/b2ap3_large_happy-sad-unsplash-850x575.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/landscape-4209944_1280.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@1020.865] global loadsave.cpp:248 findDecoder imread_('data/sad-big-SS.jpg'): can't open/read file: check file path/integrity

# %% [markdown]
# ## 1.3 Load Data

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 170 files belonging to 2 classes.
